# %%
# @desc: 利用高德API下载地理编码
 
import requests
import pandas as pd
import os
import time
import transbigdata as tbd
from time import sleep
import random
 
# 导入excel
# amp_api_data = pd.read_excel(r'input.xlsx')
# amp_api_data = pd.read_csv(r'data/fauck.csv',encoding='gbk')
amp_api_data = pd.read_excel(r'上海市.xlsx')

# # 没有上海市的地址在前面加上上海市 将POI搜索范围锁定
# if 'address' in amp_api_data and '上海市' not in amp_api_data.get('address', ''):
#     amp_api_data['address'] = '上海市' + amp_api_data.get('address', '')
# amp_api_data

#  请求地址前缀
req_url_pref = "https://restapi.amap.com/v3/geocode/geo?"
amp_api_key = '3d580a3ff9d371ea19d65d771a66baec'
result = pd.DataFrame()  # 初始化
count = 0
print("---------------------------------------------------------------")
def get_poi_from_amap():
    """
    从高德地图API下载地理编码
    """
    global result
    global count
    response = requests.get(req_url_pref, params=rep_params)
    data = response.json()  # 返回字典数据dict
    status = data["status"]
    if status != "0":
        address = data["geocodes"][0]["formatted_address"]
        lng = float(data["geocodes"][0]["location"].split(",")[0])
        lat = float(data["geocodes"][0]["location"].split(",")[1])
        wgs84_lng,wgs84_lat=tbd.gcj02towgs84(lng,lat)
        busi_data = [
            {
                "input_name": amp_api_name,
                "input_address": amp_api_address,
                "output_address": address,
                "gcj02_lng": lng,
                "gcj02_lat": lat,
                "wgs84_lng": wgs84_lng,
                "wgs84_lat": wgs84_lat
            }
        ]
    else:
        rep_params1 = {
            "key": amp_api_key,
            "address": amp_api_name,
            #"city": amp_api_city
        }
        response = requests.get(req_url_pref, params=rep_params1)
        data = response.json()
        status = data["status"]
        if status != "0":
                address = data["geocodes"][0]["formatted_address"]
                lng = float(data["geocodes"][0]["location"].split(",")[0])
                lat = float(data["geocodes"][0]["location"].split(",")[1])
                wgs84_lng,wgs84_lat=tbd.gcj02towgs84(lng,lat)
                wgs84_lng=float(wgs84_lng)
                wgs84_lat=float(wgs84_lat)
                busi_data = [
                    {
                        "input_name": amp_api_name,
                        "input_address": amp_api_address,
                        "output_address": address,
                        "gcj02_lng": lng,
                        "gcj02_lat": lat,
                        "wgs84_lng": wgs84_lng,
                        "wgs84_lat": wgs84_lat
                        }
                ]
        else:
            busi_data = [
        {
            "input_name": amp_api_name,
            "input_address": amp_api_address,
            "output_address": 'Unknow',
            "gcj02_lng": 'Unknow',
            "gcj02_lat": 'Unknow',
            "wgs84_lng": 'Unknow',
            "wgs84_lat": 'Unknow'
        }]
            count += 1
            print(count,":",amp_api_name,"未能在地图中找到位置")
    df = pd.DataFrame(busi_data)
    result = pd.concat([result, df], axis=0, ignore_index=True)   # 将每次i结果union在一块（列方面追加）
 
 
# 遍历地址
for i in range(len(amp_api_data.values)):     
    # amp_api_name = amp_api_data.values[i][0]
    # amp_api_address = amp_api_data.values[i][1] 
    amp_api_name = amp_api_data['名称'][i]
    amp_api_address = amp_api_data['地址'][i] 
    #amp_api_city = '北京市'
    #  请求参数
    rep_params = {
        "key": amp_api_key,
        "address": amp_api_address,
        #"city": amp_api_city
    }
    get_poi_from_amap()
    print("进度：[",i+1,"/",len(amp_api_data),"]", sep='')
    # time.sleep(3)
    sleep(random.randint(1, 3))
 
    
 
# 将脚本所在路径作为excel输出路径
output_path = os.getcwd() + os.sep + "shanghai_location_gd.xlsx"
# 将结果写入到output_path 所在的excel中
result.to_excel(output_path, index=False)
print("---------------经纬度获取完成(来源：高德地图)-------------------")
print("有",count,"个地址未查询到对应的经纬度")
# Out:
# ---------------------------------------------------------------
# 进度：[1/345]
# 进度：[2/345]
# 进度：[3/345]
# 进度：[4/345]
# 进度：[5/345]
# 进度：[6/345]
# 进度：[7/345]
# 进度：[8/345]
# 进度：[9/345]
# 进度：[10/345]
# 进度：[11/345]
# 进度：[12/345]
# 进度：[13/345]
# 进度：[14/345]
# 进度：[15/345]
# 进度：[16/345]
# 进度：[17/345]
# 进度：[18/345]
# 进度：[19/345]
# 进度：[20/345]
# 进度：[21/345]
# 进度：[22/345]
# 进度：[23/345]
# 进度：[24/345]
# 进度：[25/345]
# 进度：[26/345]
# 进度：[27/345]
# 进度：[28/345]
# 进度：[29/345]
# 进度：[30/345]
# 进度：[31/345]
# 进度：[32/345]
# 进度：[33/345]
# 进度：[34/345]
# 进度：[35/345]
# 进度：[36/345]
# 进度：[37/345]
# 进度：[38/345]
# 进度：[39/345]
# 进度：[40/345]
# 进度：[41/345]
# 进度：[42/345]
# 进度：[43/345]
# 进度：[44/345]
# 进度：[45/345]
# 进度：[46/345]
# 进度：[47/345]
# 进度：[48/345]
# 进度：[49/345]
# 进度：[50/345]
# 进度：[51/345]
# 进度：[52/345]
# 进度：[53/345]
# 进度：[54/345]
# 进度：[55/345]
# 进度：[56/345]
# 进度：[57/345]
# 进度：[58/345]
# 进度：[59/345]
# 进度：[60/345]
# 进度：[61/345]
# 进度：[62/345]
# 进度：[63/345]
# 进度：[64/345]
# 进度：[65/345]
# 进度：[66/345]
# 进度：[67/345]
# 进度：[68/345]
# 进度：[69/345]
# 进度：[70/345]
# 进度：[71/345]
# 进度：[72/345]
# 进度：[73/345]
# 进度：[74/345]
# 进度：[75/345]
# 进度：[76/345]
# 进度：[77/345]
# 进度：[78/345]
# 进度：[79/345]
# 进度：[80/345]
# 进度：[81/345]
# 进度：[82/345]
# 进度：[83/345]
# 进度：[84/345]
# 进度：[85/345]
# 进度：[86/345]
# 进度：[87/345]
# 进度：[88/345]
# 进度：[89/345]
# 进度：[90/345]
# 进度：[91/345]
# 进度：[92/345]
# 进度：[93/345]
# 进度：[94/345]
# 进度：[95/345]
# 进度：[96/345]
# 进度：[97/345]
# 进度：[98/345]
# 进度：[99/345]
# 进度：[100/345]
# 进度：[101/345]
# 进度：[102/345]
# 进度：[103/345]
# 进度：[104/345]
# 进度：[105/345]
# 进度：[106/345]
# 进度：[107/345]
# 进度：[108/345]
# 进度：[109/345]
# 进度：[110/345]
# 进度：[111/345]
# 进度：[112/345]
# 进度：[113/345]
# 进度：[114/345]
# 进度：[115/345]
# 进度：[116/345]
# 进度：[117/345]
# 进度：[118/345]
# 进度：[119/345]
# 进度：[120/345]
# 进度：[121/345]
# 进度：[122/345]
# 进度：[123/345]
# 进度：[124/345]
# 进度：[125/345]
# 进度：[126/345]
# 进度：[127/345]
# 进度：[128/345]
# 进度：[129/345]
# 进度：[130/345]
# 进度：[131/345]
# 进度：[132/345]
# 进度：[133/345]
# 进度：[134/345]
# 进度：[135/345]
# 进度：[136/345]
# 进度：[137/345]
# 进度：[138/345]
# 进度：[139/345]
# 进度：[140/345]
# 进度：[141/345]
# 进度：[142/345]
# 进度：[143/345]
# 进度：[144/345]
# 进度：[145/345]
# 进度：[146/345]
# 进度：[147/345]
# 进度：[148/345]
# 进度：[149/345]
# 进度：[150/345]
# 进度：[151/345]
# 进度：[152/345]
# 进度：[153/345]
# 进度：[154/345]
# 进度：[155/345]
# 进度：[156/345]
# 进度：[157/345]
# 进度：[158/345]
# 进度：[159/345]
# 进度：[160/345]
# 进度：[161/345]
# 进度：[162/345]
# 进度：[163/345]
# 进度：[164/345]
# 进度：[165/345]
# 进度：[166/345]
# 进度：[167/345]
# 进度：[168/345]
# 进度：[169/345]
# 进度：[170/345]
# 进度：[171/345]
# 进度：[172/345]
# 进度：[173/345]
# 进度：[174/345]
# 进度：[175/345]
# 进度：[176/345]
# 进度：[177/345]
# 进度：[178/345]
# 进度：[179/345]
# 进度：[180/345]
# 进度：[181/345]
# 进度：[182/345]
# 进度：[183/345]
# 进度：[184/345]
# 进度：[185/345]
# 进度：[186/345]
# 进度：[187/345]
# 进度：[188/345]
# 进度：[189/345]
# 进度：[190/345]
# 进度：[191/345]
# 进度：[192/345]
# 进度：[193/345]
# 进度：[194/345]
# 进度：[195/345]
# 进度：[196/345]
# 进度：[197/345]
# 进度：[198/345]
# 进度：[199/345]
# 进度：[200/345]
# 进度：[201/345]
# 进度：[202/345]
# 进度：[203/345]
# 进度：[204/345]
# 进度：[205/345]
# 进度：[206/345]
# 进度：[207/345]
# 进度：[208/345]
# 进度：[209/345]
# 进度：[210/345]
# 进度：[211/345]
# 进度：[212/345]
# 进度：[213/345]
# 进度：[214/345]
# 进度：[215/345]
# 进度：[216/345]
# 进度：[217/345]
# 进度：[218/345]
# 进度：[219/345]
# 进度：[220/345]
# 进度：[221/345]
# 进度：[222/345]
# 进度：[223/345]
# 进度：[224/345]
# 进度：[225/345]
# 进度：[226/345]
# 进度：[227/345]
# 进度：[228/345]
# 进度：[229/345]
# 进度：[230/345]
# 进度：[231/345]
# 进度：[232/345]
# 进度：[233/345]
# 进度：[234/345]
# 进度：[235/345]
# 进度：[236/345]
# 进度：[237/345]
# 进度：[238/345]
# 进度：[239/345]
# 进度：[240/345]
# 进度：[241/345]
# 进度：[242/345]
# 进度：[243/345]
# 进度：[244/345]
# 进度：[245/345]
# 进度：[246/345]
# 进度：[247/345]
# 进度：[248/345]
# 进度：[249/345]
# 进度：[250/345]
# 进度：[251/345]
# 进度：[252/345]
# 进度：[253/345]
# 进度：[254/345]
# 进度：[255/345]
# 进度：[256/345]
# 进度：[257/345]
# 进度：[258/345]
# 进度：[259/345]
# 进度：[260/345]
# 进度：[261/345]
# 进度：[262/345]
# 进度：[263/345]
# 进度：[264/345]
# 进度：[265/345]
# 进度：[266/345]
# 进度：[267/345]
# 进度：[268/345]
# 进度：[269/345]
# 进度：[270/345]
# 进度：[271/345]
# 进度：[272/345]
# 进度：[273/345]
# 进度：[274/345]
# 进度：[275/345]
# 进度：[276/345]
# 进度：[277/345]
# 进度：[278/345]
# 进度：[279/345]
# 进度：[280/345]
# 进度：[281/345]
# 进度：[282/345]
# 进度：[283/345]
# 进度：[284/345]
# 进度：[285/345]
# 进度：[286/345]
# 进度：[287/345]
# 进度：[288/345]
# 进度：[289/345]
# 进度：[290/345]
# 进度：[291/345]
# 进度：[292/345]
# 进度：[293/345]
# 进度：[294/345]
# 进度：[295/345]
# 进度：[296/345]
# 进度：[297/345]
# 进度：[298/345]
# 进度：[299/345]
# 进度：[300/345]
# 进度：[301/345]
# 进度：[302/345]
# 进度：[303/345]
# 进度：[304/345]
# 进度：[305/345]
# 进度：[306/345]
# 进度：[307/345]
# 进度：[308/345]
# 进度：[309/345]
# 进度：[310/345]
# 进度：[311/345]
# 进度：[312/345]
# 进度：[313/345]
# 进度：[314/345]
# 进度：[315/345]
# 进度：[316/345]
# 进度：[317/345]
# 进度：[318/345]
# 进度：[319/345]
# 进度：[320/345]
# 进度：[321/345]
# 进度：[322/345]
# 进度：[323/345]
# 进度：[324/345]
# 进度：[325/345]
# 进度：[326/345]
# 进度：[327/345]
# 进度：[328/345]
# 进度：[329/345]
# 进度：[330/345]
# 进度：[331/345]
# 进度：[332/345]
# 进度：[333/345]
# 进度：[334/345]
# 进度：[335/345]
# 进度：[336/345]
# 进度：[337/345]
# 进度：[338/345]
# 进度：[339/345]
# 进度：[340/345]
# 进度：[341/345]
# 进度：[342/345]
# 进度：[343/345]
# 进度：[344/345]
# 进度：[345/345]
# ---------------经纬度获取完成(来源：高德地图)-------------------
# 有 0 个地址未查询到对应的经纬度

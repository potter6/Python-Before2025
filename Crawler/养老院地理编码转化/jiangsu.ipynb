# %%
# @desc: 利用高德API下载地理编码
 
import requests
import pandas as pd
import os
import time
import transbigdata as tbd
from time import sleep
import random
 
# 导入excel
# amp_api_data = pd.read_excel(r'input.xlsx')
# amp_api_data = pd.read_csv(r'data/fauck.csv',encoding='gbk')
amp_api_data = pd.read_excel(r'江苏省.xlsx')

# # 没有上海市的地址在前面加上上海市 将POI搜索范围锁定
# if 'address' in amp_api_data and '上海市' not in amp_api_data.get('address', ''):
#     amp_api_data['address'] = '上海市' + amp_api_data.get('address', '')
# amp_api_data

#  请求地址前缀
req_url_pref = "https://restapi.amap.com/v3/geocode/geo?"
amp_api_key = '3d580a3ff9d371ea19d65d771a66baec'
result = pd.DataFrame()  # 初始化
count = 0
print("---------------------------------------------------------------")
def get_poi_from_amap():
    """
    从高德地图API下载地理编码
    """
    global result
    global count
    response = requests.get(req_url_pref, params=rep_params)
    data = response.json()  # 返回字典数据dict
    status = data["status"]
    if status != "0":
        address = data["geocodes"][0]["formatted_address"]
        lng = float(data["geocodes"][0]["location"].split(",")[0])
        lat = float(data["geocodes"][0]["location"].split(",")[1])
        wgs84_lng,wgs84_lat=tbd.gcj02towgs84(lng,lat)
        busi_data = [
            {
                "input_name": amp_api_name,
                "input_address": amp_api_address,
                "output_address": address,
                "gcj02_lng": lng,
                "gcj02_lat": lat,
                "wgs84_lng": wgs84_lng,
                "wgs84_lat": wgs84_lat
            }
        ]
    else:
        rep_params1 = {
            "key": amp_api_key,
            "address": amp_api_name,
            #"city": amp_api_city
        }
        response = requests.get(req_url_pref, params=rep_params1)
        data = response.json()
        status = data["status"]
        if status != "0":
                address = data["geocodes"][0]["formatted_address"]
                lng = float(data["geocodes"][0]["location"].split(",")[0])
                lat = float(data["geocodes"][0]["location"].split(",")[1])
                wgs84_lng,wgs84_lat=tbd.gcj02towgs84(lng,lat)
                wgs84_lng=float(wgs84_lng)
                wgs84_lat=float(wgs84_lat)
                busi_data = [
                    {
                        "input_name": amp_api_name,
                        "input_address": amp_api_address,
                        "output_address": address,
                        "gcj02_lng": lng,
                        "gcj02_lat": lat,
                        "wgs84_lng": wgs84_lng,
                        "wgs84_lat": wgs84_lat
                        }
                ]
        else:
            busi_data = [
        {
            "input_name": amp_api_name,
            "input_address": amp_api_address,
            "output_address": 'Unknow',
            "gcj02_lng": 'Unknow',
            "gcj02_lat": 'Unknow',
            "wgs84_lng": 'Unknow',
            "wgs84_lat": 'Unknow'
        }]
            count += 1
            print(count,":",amp_api_name,"未能在地图中找到位置")
    df = pd.DataFrame(busi_data)
    result = pd.concat([result, df], axis=0, ignore_index=True)   # 将每次i结果union在一块（列方面追加）
 
 
# 遍历地址
for i in range(len(amp_api_data.values)):     
    # amp_api_name = amp_api_data.values[i][0]
    # amp_api_address = amp_api_data.values[i][1] 
    amp_api_name = amp_api_data['名称'][i]
    amp_api_address = amp_api_data['地址'][i] 
    #amp_api_city = '北京市'
    #  请求参数
    rep_params = {
        "key": amp_api_key,
        "address": amp_api_address,
        #"city": amp_api_city
    }
    get_poi_from_amap()
    print("进度：[",i+1,"/",len(amp_api_data),"]", sep='')
    # time.sleep(3)
    sleep(random.randint(1, 3))
 
    
 
# 将脚本所在路径作为excel输出路径
output_path = os.getcwd() + os.sep + "jiangsu_location_gd.xlsx"
# 将结果写入到output_path 所在的excel中
result.to_excel(output_path, index=False)
print("---------------经纬度获取完成(来源：高德地图)-------------------")
print("有",count,"个地址未查询到对应的经纬度")
# Out:
# ---------------------------------------------------------------
# 进度：[1/384]
# 进度：[2/384]
# 进度：[3/384]
# 进度：[4/384]
# 进度：[5/384]
# 进度：[6/384]
# 进度：[7/384]
# 进度：[8/384]
# 进度：[9/384]
# 进度：[10/384]
# 进度：[11/384]
# 进度：[12/384]
# 进度：[13/384]
# 进度：[14/384]
# 进度：[15/384]
# 进度：[16/384]
# 进度：[17/384]
# 进度：[18/384]
# 进度：[19/384]
# 进度：[20/384]
# 进度：[21/384]
# 进度：[22/384]
# 进度：[23/384]
# 进度：[24/384]
# 进度：[25/384]
# 进度：[26/384]
# 进度：[27/384]
# 进度：[28/384]
# 进度：[29/384]
# 进度：[30/384]
# 进度：[31/384]
# 进度：[32/384]
# 进度：[33/384]
# 进度：[34/384]
# 进度：[35/384]
# 进度：[36/384]
# 进度：[37/384]
# 进度：[38/384]
# 进度：[39/384]
# 进度：[40/384]
# 1 : 九如城辛丰康养中心 未能在地图中找到位置
# 进度：[41/384]
# 进度：[42/384]
# 进度：[43/384]
# 进度：[44/384]
# 进度：[45/384]
# 进度：[46/384]
# 进度：[47/384]
# 进度：[48/384]
# 进度：[49/384]
# 进度：[50/384]
# 进度：[51/384]
# 进度：[52/384]
# 进度：[53/384]
# 进度：[54/384]
# 进度：[55/384]
# 进度：[56/384]
# 进度：[57/384]
# 进度：[58/384]
# 进度：[59/384]
# 进度：[60/384]
# 进度：[61/384]
# 进度：[62/384]
# 进度：[63/384]
# 进度：[64/384]
# 2 : 苏州凯乐福康养公寓 未能在地图中找到位置
# 进度：[65/384]
# 进度：[66/384]
# 进度：[67/384]
# 进度：[68/384]
# 进度：[69/384]
# 进度：[70/384]
# 3 : 桑榆堂养老院（南洲里） 未能在地图中找到位置
# 进度：[71/384]
# 4 : 康缘颐养中心 未能在地图中找到位置
# 进度：[72/384]
# 进度：[73/384]
# 进度：[74/384]
# 进度：[75/384]
# 进度：[76/384]
# 进度：[77/384]
# 进度：[78/384]
# 进度：[79/384]
# 进度：[80/384]
# 进度：[81/384]
# 进度：[82/384]
# 进度：[83/384]
# 进度：[84/384]
# 进度：[85/384]
# 进度：[86/384]
# 进度：[87/384]
# 进度：[88/384]
# 进度：[89/384]
# 进度：[90/384]
# 进度：[91/384]
# 进度：[92/384]
# 进度：[93/384]
# 5 : 南京市泰康之家·苏园高端养老公寓 未能在地图中找到位置
# 进度：[94/384]
# 进度：[95/384]
# 进度：[96/384]
# 进度：[97/384]
# 进度：[98/384]
# 进度：[99/384]
# 进度：[100/384]
# 进度：[101/384]
# 进度：[102/384]
# 进度：[103/384]
# 进度：[104/384]
# 进度：[105/384]
# 进度：[106/384]
# 进度：[107/384]
# 进度：[108/384]
# 进度：[109/384]

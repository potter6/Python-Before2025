# %%
# @desc: 利用高德API下载地理编码
 
import requests
import pandas as pd
import os
import time
import transbigdata as tbd
from time import sleep
import random
 
# 导入excel
# amp_api_data = pd.read_excel(r'input.xlsx')
# amp_api_data = pd.read_csv(r'data/fauck.csv',encoding='gbk')
amp_api_data = pd.read_excel(r'安徽省.xlsx')

# # 没有上海市的地址在前面加上上海市 将POI搜索范围锁定
# if 'address' in amp_api_data and '上海市' not in amp_api_data.get('address', ''):
#     amp_api_data['address'] = '上海市' + amp_api_data.get('address', '')
# amp_api_data

#  请求地址前缀
req_url_pref = "https://restapi.amap.com/v3/geocode/geo?"
amp_api_key = '3d580a3ff9d371ea19d65d771a66baec'
result = pd.DataFrame()  # 初始化
count = 0
print("---------------------------------------------------------------")
def get_poi_from_amap():
    """
    从高德地图API下载地理编码
    """
    global result
    global count
    response = requests.get(req_url_pref, params=rep_params)
    data = response.json()  # 返回字典数据dict
    status = data["status"]
    if status != "0":
        address = data["geocodes"][0]["formatted_address"]
        lng = float(data["geocodes"][0]["location"].split(",")[0])
        lat = float(data["geocodes"][0]["location"].split(",")[1])
        wgs84_lng,wgs84_lat=tbd.gcj02towgs84(lng,lat)
        busi_data = [
            {
                "input_name": amp_api_name,
                "input_address": amp_api_address,
                "output_address": address,
                "gcj02_lng": lng,
                "gcj02_lat": lat,
                "wgs84_lng": wgs84_lng,
                "wgs84_lat": wgs84_lat
            }
        ]
    else:
        rep_params1 = {
            "key": amp_api_key,
            "address": amp_api_name,
            #"city": amp_api_city
        }
        response = requests.get(req_url_pref, params=rep_params1)
        data = response.json()
        status = data["status"]
        if status != "0":
                address = data["geocodes"][0]["formatted_address"]
                lng = float(data["geocodes"][0]["location"].split(",")[0])
                lat = float(data["geocodes"][0]["location"].split(",")[1])
                wgs84_lng,wgs84_lat=tbd.gcj02towgs84(lng,lat)
                wgs84_lng=float(wgs84_lng)
                wgs84_lat=float(wgs84_lat)
                busi_data = [
                    {
                        "input_name": amp_api_name,
                        "input_address": amp_api_address,
                        "output_address": address,
                        "gcj02_lng": lng,
                        "gcj02_lat": lat,
                        "wgs84_lng": wgs84_lng,
                        "wgs84_lat": wgs84_lat
                        }
                ]
        else:
            busi_data = [
        {
            "input_name": amp_api_name,
            "input_address": amp_api_address,
            "output_address": 'Unknow',
            "gcj02_lng": 'Unknow',
            "gcj02_lat": 'Unknow',
            "wgs84_lng": 'Unknow',
            "wgs84_lat": 'Unknow'
        }]
            count += 1
            print(count,":",amp_api_name,"未能在地图中找到位置")
    df = pd.DataFrame(busi_data)
    result = pd.concat([result, df], axis=0, ignore_index=True)   # 将每次i结果union在一块（列方面追加）
 
 
# 遍历地址
for i in range(len(amp_api_data.values)):     
    # amp_api_name = amp_api_data.values[i][0]
    # amp_api_address = amp_api_data.values[i][1] 
    amp_api_name = amp_api_data['名称'][i]
    amp_api_address = amp_api_data['地址'][i] 
    #amp_api_city = '北京市'
    #  请求参数
    rep_params = {
        "key": amp_api_key,
        "address": amp_api_address,
        #"city": amp_api_city
    }
    get_poi_from_amap()
    print("进度：[",i+1,"/",len(amp_api_data),"]", sep='')
    # time.sleep(3)
    sleep(random.randint(1, 3))
 
    
 
# 将脚本所在路径作为excel输出路径
output_path = os.getcwd() + os.sep + "anhui_location_gd.xlsx"
# 将结果写入到output_path 所在的excel中
result.to_excel(output_path, index=False)
print("---------------经纬度获取完成(来源：高德地图)-------------------")
print("有",count,"个地址未查询到对应的经纬度")
# Out:
# ---------------------------------------------------------------
# 进度：[1/158]
# 进度：[2/158]
# 进度：[3/158]
# 进度：[4/158]
# 进度：[5/158]
# 进度：[6/158]
# 进度：[7/158]
# 进度：[8/158]
# 进度：[9/158]
# 进度：[10/158]
# 进度：[11/158]
# 进度：[12/158]
# 进度：[13/158]
# 进度：[14/158]
# 进度：[15/158]
# 进度：[16/158]
# 进度：[17/158]
# 进度：[18/158]
# 进度：[19/158]
# 进度：[20/158]
# 进度：[21/158]
# 进度：[22/158]
# 进度：[23/158]
# 进度：[24/158]
# 进度：[25/158]
# 进度：[26/158]
# 进度：[27/158]
# 进度：[28/158]
# 进度：[29/158]
# 进度：[30/158]
# 进度：[31/158]
# 进度：[32/158]
# 进度：[33/158]
# 进度：[34/158]
# 进度：[35/158]
# 进度：[36/158]
# 进度：[37/158]
# 进度：[38/158]
# 进度：[39/158]
# 1 : 琅琊区乐康老年护理中心三里亭院 未能在地图中找到位置
# 进度：[40/158]
# 进度：[41/158]
# 进度：[42/158]
# 进度：[43/158]
# 进度：[44/158]
# 进度：[45/158]
# 进度：[46/158]
# 进度：[47/158]
# 进度：[48/158]
# 进度：[49/158]
# 进度：[50/158]
# 进度：[51/158]
# 进度：[52/158]
# 进度：[53/158]
# 进度：[54/158]
# 进度：[55/158]
# 进度：[56/158]
# 进度：[57/158]
# 进度：[58/158]
# 进度：[59/158]
# 进度：[60/158]
# 进度：[61/158]
# 进度：[62/158]
# 进度：[63/158]
# 进度：[64/158]
# 进度：[65/158]
# 进度：[66/158]
# 进度：[67/158]
# 进度：[68/158]
# 进度：[69/158]
# 进度：[70/158]
# 进度：[71/158]
# 进度：[72/158]
# 进度：[73/158]
# 进度：[74/158]
# 进度：[75/158]
# 进度：[76/158]
# 进度：[77/158]
# 进度：[78/158]
# 进度：[79/158]
# 进度：[80/158]
# 进度：[81/158]
# 进度：[82/158]
# 进度：[83/158]
# 2 : 宿州市百岁缘老年公寓 未能在地图中找到位置
# 进度：[84/158]
# 进度：[85/158]
# 进度：[86/158]
# 进度：[87/158]
# 进度：[88/158]
# 进度：[89/158]
# 进度：[90/158]
# 进度：[91/158]
# 进度：[92/158]
# 进度：[93/158]
# 进度：[94/158]
# 进度：[95/158]
# 进度：[96/158]
# 进度：[97/158]
# 进度：[98/158]
# 进度：[99/158]
# 进度：[100/158]
# 3 : 上河国际养老中心 未能在地图中找到位置
# 进度：[101/158]
# 进度：[102/158]
# 4 : 安杰养生苑 未能在地图中找到位置
# 进度：[103/158]
# 进度：[104/158]
# 进度：[105/158]
# 进度：[106/158]
# 进度：[107/158]
# 进度：[108/158]
# 进度：[109/158]
# 进度：[110/158]
# 进度：[111/158]
# 进度：[112/158]
# 进度：[113/158]
# 进度：[114/158]
# 进度：[115/158]
# 进度：[116/158]
# 进度：[117/158]
# 进度：[118/158]
# 进度：[119/158]
# 进度：[120/158]
# 进度：[121/158]
# 进度：[122/158]
# 进度：[123/158]
# 进度：[124/158]
# 进度：[125/158]
# 进度：[126/158]
# 进度：[127/158]
# 进度：[128/158]
# 进度：[129/158]
# 进度：[130/158]
# 进度：[131/158]
# 进度：[132/158]
# 进度：[133/158]
# 进度：[134/158]
# 进度：[135/158]
# 进度：[136/158]
# 进度：[137/158]
# 进度：[138/158]
# 进度：[139/158]
# 进度：[140/158]
# 进度：[141/158]
# 进度：[142/158]
# 进度：[143/158]
# 进度：[144/158]
# 进度：[145/158]
# 进度：[146/158]
# 进度：[147/158]
# 进度：[148/158]
# 进度：[149/158]
# 进度：[150/158]
# 进度：[151/158]
# 进度：[152/158]
# 进度：[153/158]
# 进度：[154/158]
# 进度：[155/158]
# 进度：[156/158]
# 进度：[157/158]
# 进度：[158/158]
# ---------------经纬度获取完成(来源：高德地图)-------------------
# 有 4 个地址未查询到对应的经纬度
